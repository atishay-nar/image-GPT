# %%
# imports
import numpy as np
import matplotlib.pyplot as plt

# %%
cents = np.load('./V2/centroids_32.npy', allow_pickle=True)

img = np.load('./V2/tokenized_mnist/MNIST_tokens_32.npy', allow_pickle=True)
def plot_mnist_image(image):
    image = image.reshape(28, 28)
    plt.imshow(image)
    plt.axis('off')
    plt.show()
plt.figure(figsize=(20, 7))
for i in range(20):
    plt.subplot((i//10 + 1), 10, i+1)
    plt.imshow(cents[img[i]].reshape(28,28))
    plt.axis('off')
plt.tight_layout
plt.show()

# %%
# Out:
# float32
